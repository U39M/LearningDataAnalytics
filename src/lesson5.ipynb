# %%
import pandas as pd
df = pd.read_excel('pokemon_data.xlsx', sheet_name='Pokemon_1')

# %%
df['タイプ1'].value_counts()
# Out:
# みず       123
# ノーマル     109
# くさ        86
# むし        75
# ほのお       58
# エスパー      57
# いわ        50
# でんき       49
# あく        36
# かくとう      36
# じめん       35
# どく        35
# ゴースト      31
# ドラゴン      31
# はがね       30
# こおり       28
# フェアリー     21
# ひこう        7
# Name: タイプ1, dtype: int64

# %%
pd.DataFrame(df['タイプ1'].value_counts())
# Out:
#        タイプ1
# みず      123
# ノーマル    109
# くさ       86
# むし       75
# ほのお      58
# エスパー     57
# いわ       50
# でんき      49
# あく       36
# かくとう     36
# じめん      35
# どく       35
# ゴースト     31
# ドラゴン     31
# はがね      30
# こおり      28
# フェアリー    21
# ひこう       7

# %%
pd.DataFrame(df[['タイプ1','タイプ2']].value_counts())
# Out:
#             0
# タイプ1 タイプ2
# ノーマル ひこう   26
# くさ   どく    14
# むし   ひこう   13
#      どく    11
# みず   じめん    9
# ...        ..
# かくとう ひこう    1
# むし   ゴースト   1
# かくとう はがね    1
# エスパー かくとう   1
# かくとう ゴースト   1
#
# [157 rows x 1 columns]
